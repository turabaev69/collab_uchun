# %% [markdown]
# <a href="https://colab.research.google.com/github/turabaev69/collab_uchun/blob/main/github_uchun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
